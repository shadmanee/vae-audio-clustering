# %%
from pathlib import Path
import shutil
from config import config

# %%
root = Path("../../..") # 0-th level

# %%
DEST_DIR = root / config.METADATA_DIR / "bn"

# %%
DEST_DIR.mkdir(exist_ok=True, parents=True)

# %%
bn_meta_path = root / "manually_annotated_metadata_bn.csv"

# %%
shutil.copy(bn_meta_path, DEST_DIR / f"metadata_bn{bn_meta_path.suffix}")
# Out:
# WindowsPath('../../../data/metadata/bn/metadata_bn.csv')
