# %%
import pandas as pd
from pathlib import Path

# %%
from config import config

# %%
root = Path("../..")

# %%
en_meta_path = root / config.METADATA_DIR / "metadata_en.csv"
bn_meta_path = root / config.METADATA_DIR / "bn/metadata_bn.csv"
en_meta_path.exists(), bn_meta_path.exists() # has to be True
# Out:
# (True, True)

# %%
en_meta_df = pd.read_csv(en_meta_path)
bn_meta_df = pd.read_csv(bn_meta_path)

# %%
en_meta_df.head()
# Out:
#   audio_file_stem lyric_file_stem quadrant  \
# 0            A001            L051       Q4
# 1            A002            L052       Q4
# 2            A003            L053       Q3
# 3            A004            L054       Q3
# 4            A005            L055       Q1
#
#                                               genres  label
# 0  Jazz,Vocal Jazz,Traditional Pop,Early Pop/Rock...      2
# 1                                           Pop/Rock      2
# 2                      Soul,Pop-Soul,Smooth Soul,R&B      3
# 3                             Outlaw Country,Country      3
# 4  Dance-Rock,R&B,Contemporary Pop/Rock,Contempor...      0

# %%
bn_meta_df.head()
# Out:
#                       id                                           sentence  \
# 0  8dLOs8LK4OQ_seg_00001                   না না না না না স্বপ্নের বালুকায়
# 1  8dLOs8LK4OQ_seg_00002  কেউ কি পালুকায় যদি না আসে ভেজা দিন ইচ্ছে হিমা...
# 2  8dLOs8LK4OQ_seg_00003  থাকে অমলিন কিছু স্বপ্ন কিছু ইচ্ছে এই আমায় টেন...
# 3  8dLOs8LK4OQ_seg_00004  কেউ না জানুক আমি তো জানি আমি তোমার কেউ না জানু...
# 4  8dLOs8LK4OQ_seg_00005                  কেউ না জানো আমি তো জানি আমি তোমার
#
#   genre
# 0   Pop
# 1   Pop
# 2   Pop
# 3   Pop
# 4   Pop

# %%
en_meta_df["language"] = "en"
en_meta_df["label"] = 0
bn_meta_df["language"] = "bn"
bn_meta_df["label"] = 1
bn_meta_df.rename(columns={"id": "audio_file_stem"}, inplace=True)
en_meta_df.rename(columns={"genres": "genre"}, inplace=True)

# %%
en_meta_df
# Out:
#      audio_file_stem lyric_file_stem quadrant  \
# 0               A001            L051       Q4
# 1               A002            L052       Q4
# 2               A003            L053       Q3
# 3               A004            L054       Q3
# 4               A005            L055       Q1
# ...              ...             ...      ...
# 1983    MT0035974819    MT0035974819       Q3
# 1984    MT0036111757    MT0036111757       Q2
# 1985    MT0036368550    MT0036368550       Q1
# 1986    MT0039250520    MT0039250520       Q2
# 1987    MT0041030749    MT0041030749       Q4
#
#                                                   genre  label language
# 0     Jazz,Vocal Jazz,Traditional Pop,Early Pop/Rock...      0       en
# 1                                              Pop/Rock      0       en
# 2                         Soul,Pop-Soul,Smooth Soul,R&B      0       en
# 3                                Outlaw Country,Country      0       en
# 4     Dance-Rock,R&B,Contemporary Pop/Rock,Contempor...      0       en
# ...                                                 ...    ...      ...
# 1983                                   Country,Pop/Rock      0       en
# 1984                                           Pop/Rock      0       en
# 1985                                           Pop/Rock      0       en
# 1986                                                Rap      0       en
# 1987                                            Holiday      0       en
#
# [1988 rows x 6 columns]

# %%
bn_meta_df
# Out:
#            audio_file_stem                                           sentence  \
# 0    8dLOs8LK4OQ_seg_00001                   না না না না না স্বপ্নের বালুকায়
# 1    8dLOs8LK4OQ_seg_00002  কেউ কি পালুকায় যদি না আসে ভেজা দিন ইচ্ছে হিমা...
# 2    8dLOs8LK4OQ_seg_00003  থাকে অমলিন কিছু স্বপ্ন কিছু ইচ্ছে এই আমায় টেন...
# 3    8dLOs8LK4OQ_seg_00004  কেউ না জানুক আমি তো জানি আমি তোমার কেউ না জানু...
# 4    8dLOs8LK4OQ_seg_00005                  কেউ না জানো আমি তো জানি আমি তোমার
# ..                     ...                                                ...
# 336  Z4HpPn56LaQ_seg_00005  না অন্ধকারে হাতরে বেড়ায় মনের ভেতর চলছে লড়াই...
# 337  Z4HpPn56LaQ_seg_00006  দাঁড়ায় অদ্ভুত সব মানুষগুলো কিসের খোঁজে ছুটছে...
# 338  Z4HpPn56LaQ_seg_00007                মাঠ পেরিয়ে ছোট্ট বাজার হাট পেরিয়ে
# 339  Z4HpPn56LaQ_seg_00008  পথ ভুলে গেছি অচেনা এই ইট পাথরের শহরে মিশে আছে ...
# 340  Z4HpPn56LaQ_seg_00009  যদি সত্যি মেলে মুক্তি আমি ফিরবো না কখনো কোন দে...
#
#               genre language  label
# 0               Pop       bn      1
# 1               Pop       bn      1
# 2               Pop       bn      1
# 3               Pop       bn      1
# 4               Pop       bn      1
# ..              ...      ...    ...
# 336  Indie/Folk-Pop       bn      1
# 337  Indie/Folk-Pop       bn      1
# 338  Indie/Folk-Pop       bn      1
# 339  Indie/Folk-Pop       bn      1
# 340  Indie/Folk-Pop       bn      1
#
# [341 rows x 5 columns]

# %%
bn_meta_df[bn_meta_df["audio_file_stem"] == "-Bfa-aVa7MU_seg_00002"]
# Out:
#           audio_file_stem                                         sentence  \
# 27  -Bfa-aVa7MU_seg_00002  দূরু তোমার উতাস চুলের ভাজে মৃদু যোছনা মাখা গন্ধ
#
#    genre language  label
# 27  Rock       bn      1

# %%
combined_meta_df = pd.concat([en_meta_df[["audio_file_stem", "language", "label", "genre"]], bn_meta_df[["audio_file_stem", "language", "label", "genre"]]], axis=0)
combined_meta_df.reset_index(drop=True, inplace=True)

# %%
combined_meta_df
# Out:
#             audio_file_stem language  label  \
# 0                      A001       en      0
# 1                      A002       en      0
# 2                      A003       en      0
# 3                      A004       en      0
# 4                      A005       en      0
# ...                     ...      ...    ...
# 2324  Z4HpPn56LaQ_seg_00005       bn      1
# 2325  Z4HpPn56LaQ_seg_00006       bn      1
# 2326  Z4HpPn56LaQ_seg_00007       bn      1
# 2327  Z4HpPn56LaQ_seg_00008       bn      1
# 2328  Z4HpPn56LaQ_seg_00009       bn      1
#
#                                                   genre
# 0     Jazz,Vocal Jazz,Traditional Pop,Early Pop/Rock...
# 1                                              Pop/Rock
# 2                         Soul,Pop-Soul,Smooth Soul,R&B
# 3                                Outlaw Country,Country
# 4     Dance-Rock,R&B,Contemporary Pop/Rock,Contempor...
# ...                                                 ...
# 2324                                     Indie/Folk-Pop
# 2325                                     Indie/Folk-Pop
# 2326                                     Indie/Folk-Pop
# 2327                                     Indie/Folk-Pop
# 2328                                     Indie/Folk-Pop
#
# [2329 rows x 4 columns]

# %%
DEST_PATH = root / config.METADATA_DIR / "metadata_en_bn.csv"
combined_meta_df.to_csv(DEST_PATH, index=False)
